# %% [markdown]
# # Load

# %%
import pandas as pd

train_trans = pd.read_csv("/Users/hassan/Library/CloudStorage/OneDrive-HigherEducationCommission/ML-Project-hehe/Dataset/train_transaction.csv")
train_id = pd.read_csv("/Users/hassan/Library/CloudStorage/OneDrive-HigherEducationCommission/ML-Project-hehe/Dataset/train_identity.csv")

print(train_trans.shape)
print(train_id.shape)
# Out:
# (590540, 394)
# (144233, 41)

# %% [markdown]
# # Merge

# %%
train = train_trans.merge(train_id, on="TransactionID", how="left")

print(train.shape)
# Out:
# (590540, 434)
