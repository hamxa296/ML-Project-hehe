# %% [markdown]
# # 🌲 Model 07 — Random Forest
#
# Comparing performance between Balanced and Unbalanced training.

# %%
import os
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, precision_recall_curve, auc

test = pd.read_csv('../data/test.csv')
X_test = test.drop(columns=['isFraud', 'TransactionID'], errors='ignore')
y_test = test['isFraud']

def run_rf(train_path, label):
    print(f'\n--- Training on {label} ---')
    train = pd.read_csv(train_path)
    X_train = train.drop(columns=['isFraud', 'TransactionID'], errors='ignore')
    y_train = train['isFraud']
    model = RandomForestClassifier(n_estimators=100, max_depth=15, n_jobs=-1, random_state=42)
    model.fit(X_train, y_train)
    probs = model.predict_proba(X_test)[:, 1]
    precision, recall, _ = precision_recall_curve(y_test, probs)
    print(f'PR-AUC: {auc(recall, precision):.4f}')

run_rf('../data/train_unbalanced.csv', 'UNBALANCED')
run_rf('../data/train_balanced.csv', 'BALANCED')
# Out:
# --- Training on UNBALANCED ---
# PR-AUC: 0.6157
#
# --- Training on BALANCED ---
# PR-AUC: 0.5818
